# %%
import geopandas as gpd
import os
import shutil
from zipfile import ZipFile
import json

# %%
def create_user_folder(username):
    # Path direktori utama
    base_dir = 'upload/output'

    # Path direktori user
    user_dir = os.path.join(base_dir, username)

    # Membuat direktori user jika belum ada
    os.makedirs(user_dir, exist_ok=True)

    return user_dir

# %%
def create_zip_folder(username, user_dir):
    # Membuat folder user
    # user_dir = create_user_folder(username)
    # print(f"user_dir: {user_dir}")

    # Path direktori yang akan di-zip
    source_dir = user_dir

    # Path file ZIP keluaran
    zip_file = f'upload/output/zip/{username}.zip'

    # Membuat file ZIP dari folder
    with ZipFile(zip_file, 'w') as zipf:
        # Menambahkan isi folder ke dalam ZIP
        for foldername, subfolders, filenames in os.walk(source_dir):
            for filename in filenames:
                # Path file yang akan dimasukkan ke dalam ZIP
                file_path = os.path.join(foldername, filename)
                # Path relatif file dalam ZIP
                rel_path = os.path.relpath(file_path, source_dir)
                zipf.write(file_path, rel_path)

    return zip_file

# %%
# Path file GeoJSON yang akan dikonversi
geojson_file = 'upload/files/Indonesian_drawing_by_アフマド.geojson'

# Ambil nama file dari path GeoJSON
geojson_filename = os.path.splitext(os.path.basename(geojson_file))[0]

# Gunakan nama file GeoJSON sebagai nama pengguna (username)
username = geojson_filename

# %%
# Path file Shapefile keluaran tanpa ekstensi
user_dir = create_user_folder(username)
shapefile_output = user_dir

# Membaca data GeoJSON menggunakan geopandas
gdf = gpd.read_file(geojson_file)
print(gdf)
# Out:
#                                   id  \
# 0   64647ef5cde421b4aad6c48a98c09397
# 1   8a2741800c4aa744982db12dabadf79f
# 2   f1d9550913fa6f54b35146bac8c4e52d
# 3   c14aef57d90ba954c0071f8d172ca65a
# 4   47664481304c10e2e1cb1343be920ccf
# 5   dd4cff9c0741fa6ca15543df3d6efc8d
# 6   80b9f21cf303cfcbd5bf3abed2dc0dad
# 7   427845d3819aa440df290ca53eb2b333
# 8   5e74c163cb5715da6aacf9ac36d0c323
# 9   21cc3cad555727353613e9f96e772089
# 10  53fe91504826e94fa07122289ee8b0a6
# 11  a608f427aead65192800e1299da65347
# 12  43a181d0b765a6aac5be79d7a764e949
# 13  f85288d2e2229a269d81c0264cc7e354
# 14  1c2c7e16a0aca1a63627e4e91d45f933
# 15  b060ee97e0a03a8329be5a942736fbc4
# 16  ed26f28c528a00d1f954a0ef9e5e9779
#
#                                     formatted_address street_number  \
# 0   Jl. Taman Mini Indonesia Indah No.10, RW.2, Ce...            10
# 1   Jl. Taman Mini Indonesia Indah No.10, Ceger, K...            10
# 2   Jl. Taman Mini Indonesia Indah No.10, Ceger, K...            10
# 3   Jl. Taman Mini Indonesia Indah No.10, RW.2, Ce...            10
# 4   Jl. Taman Mini Indonesia Indah No.2, Ceger, Ke...             2
# 5   Area Tmii No.7, RW.2, Ceger, Kec. Cipayung, Ko...             7
# 6   Area Tmii No.7, RW.2, Ceger, Kec. Cipayung, Ko...             7
# 7   Area Tmii No.7, RW.2, Ceger, Kec. Cipayung, Ko...             7
# 8   Jl. Erawati No.577, RT.7/RW.3, Halim Perdana K...        No.577
# 9   Jl. Erawati No.577, RT.7/RW.3, Halim Perdana K...        No.577
# 10  Jl. Erawati No.577, RT.7/RW.3, Halim Perdana K...        No.577
# 11  Jl. Erawati No.577, RT.7/RW.3, Halim Perdana K...        No.577
# 12  Jl. Erawati No.577, RT.7/RW.3, Halim Perdana K...        No.577
# 13  Jl. Erawati No.577, RT.7/RW.3, Halim Perdana K...        No.577
# 14  Jl. Taman Mini Indonesia Indah No.10, RW.2, Ce...            10
# 15  Jl. Erawati No.577, RT.7/RW.3, Halim Perdana K...        No.577
# 16  Jl. Erawati No.577, RT.7/RW.3, Halim Perdana K...        No.577
#
#                                route administrative_area_level_7  \
# 0   Jalan Taman Mini Indonesia Indah                        None
# 1   Jalan Taman Mini Indonesia Indah                        None
# 2   Jalan Taman Mini Indonesia Indah                        None
# 3   Jalan Taman Mini Indonesia Indah                        None
# 4   Jalan Taman Mini Indonesia Indah                        None
# 5                          Area Tmii                        None
# 6                          Area Tmii                        None
# 7                          Area Tmii                        None
# 8                        Jl. Erawati                       RT 07
# 9                        Jl. Erawati                       RT 07
# 10                       Jl. Erawati                       RT 07
# 11                       Jl. Erawati                       RT 07
# 12                       Jl. Erawati                       RT 07
# 13                       Jl. Erawati                       RT 07
# 14  Jalan Taman Mini Indonesia Indah                        None
# 15                       Jl. Erawati                       RT 07
# 16                       Jl. Erawati                       RT 07
#
#    administrative_area_level_6 administrative_area_level_4  \
# 0                         None                       Ceger
# 1                         None                       Ceger
# 2                         None                       Ceger
# 3                         None                       Ceger
# 4                         None                       Ceger
# 5                         None                       Ceger
# 6                         None                       Ceger
# 7                         None                       Ceger
# 8                        RW 03       Halim Perdana Kusumah
# 9                        RW 03       Halim Perdana Kusumah
# 10                       RW 03       Halim Perdana Kusumah
# 11                       RW 03       Halim Perdana Kusumah
# 12                       RW 03       Halim Perdana Kusumah
# 13                       RW 03       Halim Perdana Kusumah
# 14                        None                       Ceger
# 15                       RW 03       Halim Perdana Kusumah
# 16                       RW 03       Halim Perdana Kusumah
#
#    administrative_area_level_3 administrative_area_level_2  \
# 0           Kecamatan Cipayung          Kota Jakarta Timur
# 1           Kecamatan Cipayung          Kota Jakarta Timur
# 2           Kecamatan Cipayung          Kota Jakarta Timur
# 3           Kecamatan Cipayung          Kota Jakarta Timur
# 4           Kecamatan Cipayung          Kota Jakarta Timur
# 5           Kecamatan Cipayung          Kota Jakarta Timur
# 6           Kecamatan Cipayung          Kota Jakarta Timur
# 7           Kecamatan Cipayung          Kota Jakarta Timur
# 8            Kecamatan Makasar          Kota Jakarta Timur
# 5    DKI Jakarta  Indonesian_drawing_by_アフマド
# 6    DKI Jakarta  Indonesian_drawing_by_アフマド
# 7    DKI Jakarta  Indonesian_drawing_by_アフマド
# 8           None  Indonesian_drawing_by_アフマド
# 9           None  Indonesian_drawing_by_アフマド
# 10          None  Indonesian_drawing_by_アフマド
# 11          None  Indonesian_drawing_by_アフマド
# 12          None  Indonesian_drawing_by_アフマド
# 13          None  Indonesian_drawing_by_アフマド
# 14          None  Indonesian_drawing_by_アフマド
# 15          None  Indonesian_drawing_by_アフマド
# 16          None  Indonesian_drawing_by_アフマド
#
#                                              geometry
# 0   POLYGON ((106.89732 -6.30116, 106.89726 -6.301...
# 1   POLYGON ((106.89441 -6.30083, 106.89444 -6.300...
# 2   POLYGON ((106.89541 -6.30155, 106.89542 -6.301...
# 3   POLYGON ((106.89896 -6.30153, 106.89897 -6.302...
# 4   POLYGON ((106.89658 -6.30064, 106.89663 -6.300...
# 5   POLYGON ((106.89545 -6.30202, 106.89545 -6.302...
# 6   POLYGON ((106.89617 -6.30204, 106.89623 -6.302...
# 7   MULTIPOLYGON (((106.89635 -6.30215, 106.89635 ...
# 8   POLYGON ((106.89722 -6.30233, 106.89725 -6.302...
# 9   POLYGON ((106.89760 -6.30169, 106.89761 -6.301...
# 10  POLYGON ((106.89769 -6.30164, 106.89770 -6.301...
# 11  POLYGON ((106.89749 -6.30148, 106.89734 -6.301...
# 12  POLYGON ((106.89762 -6.30146, 106.89764 -6.301...
# 13  POLYGON ((106.89768 -6.30137, 106.89768 -6.301...
# 14  POLYGON ((106.89772 -6.30139, 106.89771 -6.301...
# 15  POLYGON ((106.89730 -6.30214, 106.89731 -6.302...
# 16  POLYGON ((106.89748 -6.30210, 106.89749 -6.302...

# %%
# Menyimpan data GeoJSON sebagai Shapefile lengkap
gdf.to_file(shapefile_output, driver='ESRI Shapefile', encoding='utf-8')

# buat zip file untuk dikirim ke backend
zip_file = create_zip_folder(username, user_dir)

# Contoh data yang akan diubah ke format JSON
data = {
    "filename": username,
    "geojson_file": geojson_file,
    "zip_file": zip_file,
    "file_url": "https://example.com/upload/output/john_doe.zip",
    "status": "success",
    "message": "Convert GeoJSON To Shapefile Finished..."
}

# Mengubah data ke format JSON
json_output = json.dumps(data)

# Mencetak output JSON
print(json_output)
# Out:
# {"filename": "Indonesian_drawing_by_\u30a2\u30d5\u30de\u30c9", "geojson_file": "upload/files/Indonesian_drawing_by_\u30a2\u30d5\u30de\u30c9.geojson", "zip_file": "upload/output/zip/Indonesian_drawing_by_\u30a2\u30d5\u30de\u30c9.zip", "file_url": "https://example.com/upload/output/john_doe.zip", "status": "success", "message": "Convert GeoJSON To Shapefile Finished..."}
# <ipython-input-40-4623c57f2c74>:2: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gdf.to_file(shapefile_output, driver='ESRI Shapefile', encoding='utf-8')
